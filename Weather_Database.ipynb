# %%
# Deliverable 1
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 770

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=63f3b54827a2c70303fcf70746528289

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Run an API request for each of the cities.

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_country = city_weather["sys"]["country"]
        city_percent_humidity = city_weather["main"]["humidity"]
        city_percent_cloudiness = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
              "Country": city_country,
              "Lat": city_lat,
              "Lng": city_lng,
              "Maximum Hemperature": city_max_temp,
              "Percent Humidity": city_percent_humidity,
              "Percent Cloudiness": city_percent_cloudiness,
              "Wind Speed": city_wind,
              "Weather description": city_desc})
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

    
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | euclides da cunha
# Processing Record 2 of Set 1 | buarcos
# Processing Record 3 of Set 1 | pueblo nuevo
# Processing Record 4 of Set 1 | hohhot
# Processing Record 5 of Set 1 | yebaishou
# Processing Record 6 of Set 1 | bluff
# Processing Record 7 of Set 1 | sumbawa
# City not found. Skipping...
# Processing Record 8 of Set 1 | bambous virieux
# Processing Record 9 of Set 1 | accra
# Processing Record 10 of Set 1 | victor harbor
# Processing Record 11 of Set 1 | salinopolis
# Processing Record 12 of Set 1 | tasiilaq
# Processing Record 13 of Set 1 | punta arenas
# Processing Record 14 of Set 1 | barrow
# Processing Record 15 of Set 1 | port alfred
# Processing Record 16 of Set 1 | puerto ayora
# Processing Record 17 of Set 1 | yura
# Processing Record 18 of Set 1 | haines junction
# Processing Record 19 of Set 1 | hermanus
# Processing Record 20 of Set 1 | bethel
# Processing Record 21 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 23 of Set 1 | minab
# Processing Record 24 of Set 1 | cape town
# Processing Record 25 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 26 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 1 | sitka
# Processing Record 28 of Set 1 | butaritari
# Processing Record 29 of Set 1 | esperance
# Processing Record 30 of Set 1 | korla
# Processing Record 31 of Set 1 | cotonou
# Processing Record 32 of Set 1 | albany
# Processing Record 33 of Set 1 | machiques
# Processing Record 34 of Set 1 | longyearbyen
# Processing Record 35 of Set 1 | qaanaaq
# Processing Record 36 of Set 1 | caravelas
# Processing Record 37 of Set 1 | rikitea
# Processing Record 38 of Set 1 | clyde river
# Processing Record 39 of Set 1 | lagoa
# Processing Record 40 of Set 1 | wulanhaote
# City not found. Skipping...
# Processing Record 41 of Set 1 | tukrah
# Processing Record 42 of Set 1 | atuona
# Processing Record 43 of Set 1 | lazaro cardenas
# Processing Record 44 of Set 1 | khatanga
# Processing Record 45 of Set 1 | camacha
# Processing Record 46 of Set 1 | ushuaia
# Processing Record 47 of Set 1 | mataura
# Processing Record 48 of Set 1 | chaohu
# Processing Record 49 of Set 1 | te anau
# Processing Record 50 of Set 1 | bontang
# Processing Record 1 of Set 2 | torbay
# Processing Record 2 of Set 2 | avera
# Processing Record 3 of Set 2 | thompson
# Processing Record 4 of Set 2 | ostrovnoy
# Processing Record 5 of Set 2 | loandjili
# Processing Record 6 of Set 2 | kaimur
# City not found. Skipping...
# Processing Record 7 of Set 2 | saskylakh
# Processing Record 8 of Set 2 | hobart
# Processing Record 9 of Set 2 | berlevag
# Processing Record 10 of Set 2 | jamestown
# Processing Record 11 of Set 2 | new norfolk
# Processing Record 12 of Set 2 | yellowknife
# Processing Record 13 of Set 2 | ossora
# Processing Record 14 of Set 2 | souillac
# Processing Record 15 of Set 2 | tautira
# Processing Record 16 of Set 2 | luderitz
# Processing Record 17 of Set 2 | campestre
# Processing Record 18 of Set 2 | faanui
# Processing Record 19 of Set 2 | castro
# Processing Record 20 of Set 2 | georgetown
# Processing Record 21 of Set 2 | chake chake
# Processing Record 22 of Set 2 | hazorasp
# Processing Record 23 of Set 2 | ancud
# Processing Record 24 of Set 2 | itarema
# Processing Record 25 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 26 of Set 2 | rio grande
# Processing Record 27 of Set 2 | port elizabeth
# Processing Record 28 of Set 2 | parana
# Processing Record 29 of Set 2 | birjand
# Processing Record 30 of Set 2 | fortuna
# Processing Record 31 of Set 2 | darhan
# Processing Record 32 of Set 2 | saint-philippe
# Processing Record 33 of Set 2 | karratha
# Processing Record 34 of Set 2 | arroyo
# Processing Record 35 of Set 2 | destin
# Processing Record 36 of Set 2 | am timan
# Processing Record 37 of Set 2 | hithadhoo
# Processing Record 38 of Set 2 | irklievskaya
# City not found. Skipping...
# Processing Record 39 of Set 2 | sapa
# Processing Record 40 of Set 2 | benghazi
# Processing Record 41 of Set 2 | port keats
# Processing Record 42 of Set 2 | tiksi
# Processing Record 43 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 44 of Set 2 | ponta do sol
# Processing Record 45 of Set 2 | dujuma
# City not found. Skipping...
# Processing Record 46 of Set 2 | vincennes
# Processing Record 47 of Set 2 | parys
# Processing Record 48 of Set 2 | potgietersrus
# City not found. Skipping...
# Processing Record 49 of Set 2 | lebu
# Processing Record 50 of Set 2 | aripuana
# Processing Record 1 of Set 3 | avarua
# Processing Record 2 of Set 3 | bilibino
# Processing Record 3 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 3 | artyk
# City not found. Skipping...
# Processing Record 5 of Set 3 | gbarnga
# Processing Record 6 of Set 3 | busselton
# Processing Record 7 of Set 3 | broome
# Processing Record 8 of Set 3 | east london
# Processing Record 9 of Set 3 | bathsheba
# Processing Record 10 of Set 3 | katangli
# Processing Record 11 of Set 3 | sao filipe
# Processing Record 12 of Set 3 | juazeiro
# Processing Record 13 of Set 3 | sao gabriel da cachoeira
# Processing Record 14 of Set 3 | geraldton
# Processing Record 15 of Set 3 | noshiro
# Processing Record 16 of Set 3 | vestmanna
# Processing Record 17 of Set 3 | umm kaddadah
# Processing Record 18 of Set 3 | sur
# Processing Record 19 of Set 3 | sola
# Processing Record 20 of Set 3 | vaini
# Processing Record 21 of Set 3 | domoni
# Processing Record 22 of Set 3 | severo-kurilsk
# Processing Record 23 of Set 3 | tezu
# Processing Record 24 of Set 3 | zhuhai
# Processing Record 25 of Set 3 | boende
# Processing Record 26 of Set 3 | paita
# Processing Record 27 of Set 3 | tapaua
# City not found. Skipping...
# Processing Record 28 of Set 3 | imphal
# Processing Record 29 of Set 3 | strezhevoy
# Processing Record 30 of Set 3 | starosubkhangulovo
# Processing Record 31 of Set 3 | saint george
# Processing Record 32 of Set 3 | banyuwangi
# Processing Record 33 of Set 3 | gravdal
# Processing Record 34 of Set 3 | tuatapere
# Processing Record 35 of Set 3 | codrington
# Processing Record 36 of Set 3 | san quintin
# Processing Record 37 of Set 3 | guerrero negro
# Processing Record 38 of Set 3 | ribeira grande
# Processing Record 39 of Set 3 | boundiali
# Processing Record 40 of Set 3 | savonlinna
# Processing Record 41 of Set 3 | tuktoyaktuk
# Processing Record 42 of Set 3 | victoria
# Processing Record 43 of Set 3 | port hardy
# Processing Record 44 of Set 3 | bredasdorp
# Processing Record 45 of Set 3 | kavaratti
# Processing Record 46 of Set 3 | lokosovo
# Processing Record 47 of Set 3 | manono
# Processing Record 48 of Set 3 | palaiopirgos
# City not found. Skipping...
# Processing Record 49 of Set 3 | finschhafen
# Processing Record 50 of Set 3 | malpe
# Processing Record 1 of Set 4 | zhanaozen
# Processing Record 2 of Set 4 | adrar
# Processing Record 3 of Set 4 | kuttigen
# Processing Record 4 of Set 4 | altensteig
# Processing Record 5 of Set 4 | ust-kuyga
# Processing Record 6 of Set 4 | tougan
# Processing Record 7 of Set 4 | harindanga
# Processing Record 8 of Set 4 | arraial do cabo
# Processing Record 9 of Set 4 | terra santa
# Processing Record 10 of Set 4 | tawkar
# City not found. Skipping...
# Processing Record 11 of Set 4 | hilo
# Processing Record 12 of Set 4 | iquique
# Processing Record 13 of Set 4 | paracuru
# Processing Record 14 of Set 4 | half moon bay
# Processing Record 15 of Set 4 | port lincoln
# Processing Record 16 of Set 4 | maputo
# Processing Record 17 of Set 4 | lorengau
# Processing Record 18 of Set 4 | villa guerrero
# Processing Record 19 of Set 4 | kapaa
# Processing Record 20 of Set 4 | shieli
# Processing Record 21 of Set 4 | kavieng
# Processing Record 22 of Set 4 | myingyan
# Processing Record 23 of Set 4 | lesosibirsk
# Processing Record 24 of Set 4 | hasaki
# Processing Record 25 of Set 4 | trincomalee
# Processing Record 26 of Set 4 | la libertad
# Processing Record 27 of Set 4 | nanortalik
# Processing Record 28 of Set 4 | cherskiy
# Processing Record 29 of Set 4 | nador
# Processing Record 30 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 31 of Set 4 | narasaraopet
# Processing Record 32 of Set 4 | bosobolo
# Processing Record 33 of Set 4 | snezhnogorsk
# Processing Record 34 of Set 4 | eldorado
# Processing Record 35 of Set 4 | las varas
# Processing Record 36 of Set 4 | pensilvania
# Processing Record 37 of Set 4 | alvaraes
# Processing Record 38 of Set 4 | nizhnyaya tavda
# Processing Record 39 of Set 4 | lompoc
# Processing Record 40 of Set 4 | pershotravneve
# Processing Record 41 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 42 of Set 4 | levelland
# Processing Record 43 of Set 4 | deputatskiy
# Processing Record 44 of Set 4 | egvekinot
# Processing Record 45 of Set 4 | iqaluit
# Processing Record 46 of Set 4 | chokurdakh
# Processing Record 47 of Set 4 | nautla
# Processing Record 48 of Set 4 | primo tapia
# Processing Record 49 of Set 4 | coquimbo
# Processing Record 50 of Set 4 | tuy hoa
# Processing Record 1 of Set 5 | randolph
# Processing Record 2 of Set 5 | vardo
# Processing Record 3 of Set 5 | nipawin
# Processing Record 4 of Set 5 | thiruvananthapuram
# Processing Record 5 of Set 5 | krasnyy kholm
# Processing Record 6 of Set 5 | richards bay
# Processing Record 7 of Set 5 | talnakh
# Processing Record 8 of Set 5 | namibe
# Processing Record 9 of Set 5 | hervey bay
# Processing Record 10 of Set 5 | buchanan
# Processing Record 11 of Set 5 | halifax
# Processing Record 12 of Set 5 | bilgoraj
# Processing Record 13 of Set 5 | faya
# Processing Record 14 of Set 5 | taixing
# Processing Record 15 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 16 of Set 5 | meulaboh
# Processing Record 17 of Set 5 | carnarvon
# Processing Record 18 of Set 5 | mar del plata
# Processing Record 19 of Set 5 | palembang
# Processing Record 20 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 5 | banda aceh
# Processing Record 22 of Set 5 | nagato
# Processing Record 23 of Set 5 | lavrentiya
# Processing Record 24 of Set 5 | tazovskiy
# Processing Record 25 of Set 5 | kaeo
# Processing Record 26 of Set 5 | visnes
# Processing Record 27 of Set 5 | portland
# Processing Record 28 of Set 5 | flinders
# Processing Record 29 of Set 5 | murgab
# Processing Record 30 of Set 5 | ettenheim
# Processing Record 31 of Set 5 | alofi
# Processing Record 32 of Set 5 | terrace bay
# Processing Record 33 of Set 5 | dingle
# Processing Record 34 of Set 5 | nouadhibou
# Processing Record 35 of Set 5 | chuy
# Processing Record 36 of Set 5 | ponta delgada
# Processing Record 37 of Set 5 | novyy urengoy
# Processing Record 38 of Set 5 | airai
# Processing Record 39 of Set 5 | ambulu
# Processing Record 40 of Set 5 | valdosta
# Processing Record 41 of Set 5 | tsuruoka
# Processing Record 42 of Set 5 | rockledge
# Processing Record 43 of Set 5 | kodiak
# Processing Record 44 of Set 5 | brae
# Processing Record 45 of Set 5 | saint anthony
# Processing Record 46 of Set 5 | bereda
# Processing Record 47 of Set 5 | maxixe
# Processing Record 48 of Set 5 | dalvik
# Processing Record 49 of Set 5 | pevek
# Processing Record 50 of Set 5 | yeppoon
# Processing Record 1 of Set 6 | xai-xai
# Processing Record 2 of Set 6 | sioux lookout
# Processing Record 3 of Set 6 | along
# Processing Record 4 of Set 6 | filimonovo
# Processing Record 5 of Set 6 | butembo
# Processing Record 6 of Set 6 | saint-joseph
# Processing Record 7 of Set 6 | spassk-ryazanskiy
# Processing Record 8 of Set 6 | dongsheng
# Processing Record 9 of Set 6 | homer
# Processing Record 10 of Set 6 | los llanos de aridane
# Processing Record 11 of Set 6 | muriti
# Processing Record 12 of Set 6 | mamallapuram
# Processing Record 13 of Set 6 | karauzyak
# City not found. Skipping...
# Processing Record 14 of Set 6 | swellendam
# Processing Record 15 of Set 6 | bosaso
# Processing Record 16 of Set 6 | lagunas
# Processing Record 17 of Set 6 | saldanha
# Processing Record 18 of Set 6 | ilulissat
# Processing Record 19 of Set 6 | port blair
# Processing Record 20 of Set 6 | rawson
# Processing Record 21 of Set 6 | eyl
# Processing Record 22 of Set 6 | inhambane
# Processing Record 23 of Set 6 | rafsanjan
# Processing Record 24 of Set 6 | aneho
# Processing Record 25 of Set 6 | bubaque
# Processing Record 26 of Set 6 | tabou
# Processing Record 27 of Set 6 | cabo san lucas
# Processing Record 28 of Set 6 | bafra
# Processing Record 29 of Set 6 | neuquen
# Processing Record 30 of Set 6 | henties bay
# Processing Record 31 of Set 6 | riyadh
# Processing Record 32 of Set 6 | bayevo
# Processing Record 33 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 34 of Set 6 | kenai
# Processing Record 35 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 36 of Set 6 | gazanjyk
# Processing Record 37 of Set 6 | nikolskoye
# Processing Record 38 of Set 6 | mahebourg
# Processing Record 39 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 6 | honiara
# Processing Record 41 of Set 6 | acapulco
# Processing Record 42 of Set 6 | cordoba
# Processing Record 43 of Set 6 | norman wells
# Processing Record 44 of Set 6 | san ignacio
# Processing Record 45 of Set 6 | vostok
# Processing Record 46 of Set 6 | antofagasta
# Processing Record 47 of Set 6 | brahmapuri
# City not found. Skipping...
# Processing Record 48 of Set 6 | kozan
# Processing Record 49 of Set 6 | touros
# Processing Record 50 of Set 6 | hambantota
# Processing Record 1 of Set 7 | klaksvik
# Processing Record 2 of Set 7 | asfi
# Processing Record 3 of Set 7 | aksha
# Processing Record 4 of Set 7 | tigil
# Processing Record 5 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 7 | bentiu
# Processing Record 7 of Set 7 | nouakchott
# Processing Record 8 of Set 7 | doka
# Processing Record 9 of Set 7 | tambura
# Processing Record 10 of Set 7 | maceio
# Processing Record 11 of Set 7 | gerash
# Processing Record 12 of Set 7 | stornoway
# Processing Record 13 of Set 7 | ahuimanu
# Processing Record 14 of Set 7 | ahipara
# Processing Record 15 of Set 7 | okhotsk
# Processing Record 16 of Set 7 | santa rosa
# Processing Record 17 of Set 7 | tiznit
# Processing Record 18 of Set 7 | kaitangata
# Processing Record 19 of Set 7 | chabahar
# Processing Record 20 of Set 7 | provideniya
# Processing Record 21 of Set 7 | el balyana
# City not found. Skipping...
# Processing Record 22 of Set 7 | komsomolskiy
# Processing Record 23 of Set 7 | hushitai
# Processing Record 24 of Set 7 | cap malheureux
# Processing Record 25 of Set 7 | broken hill
# Processing Record 26 of Set 7 | krotovka
# Processing Record 27 of Set 7 | ikom
# Processing Record 28 of Set 7 | seymchan
# Processing Record 29 of Set 7 | lata
# Processing Record 30 of Set 7 | vila franca do campo
# Processing Record 31 of Set 7 | zlatoustovsk
# City not found. Skipping...
# Processing Record 32 of Set 7 | makarov
# Processing Record 33 of Set 7 | ulladulla
# Processing Record 34 of Set 7 | beirut
# Processing Record 35 of Set 7 | asau
# Processing Record 36 of Set 7 | osmena
# Processing Record 37 of Set 7 | cidreira
# Processing Record 38 of Set 7 | gat
# Processing Record 39 of Set 7 | kisangani
# Processing Record 40 of Set 7 | paoua
# Processing Record 41 of Set 7 | eureka
# Processing Record 42 of Set 7 | alvik
# Processing Record 43 of Set 7 | rio de janeiro
# Processing Record 44 of Set 7 | san francisco
# Processing Record 45 of Set 7 | salym
# Processing Record 46 of Set 7 | great yarmouth
# Processing Record 47 of Set 7 | neiafu
# Processing Record 48 of Set 7 | kimbe
# Processing Record 49 of Set 7 | makhachkala
# Processing Record 50 of Set 7 | gandara
# Processing Record 1 of Set 8 | xinmin
# Processing Record 2 of Set 8 | santa cruz
# Processing Record 3 of Set 8 | pauini
# Processing Record 4 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 5 of Set 8 | constitucion
# Processing Record 6 of Set 8 | bushehr
# Processing Record 7 of Set 8 | khash
# Processing Record 8 of Set 8 | hamilton
# Processing Record 9 of Set 8 | braganca
# Processing Record 10 of Set 8 | lerwick
# Processing Record 11 of Set 8 | svobodnyy
# Processing Record 12 of Set 8 | yulara
# Processing Record 13 of Set 8 | malakal
# Processing Record 14 of Set 8 | rundu
# Processing Record 15 of Set 8 | zhuanghe
# Processing Record 16 of Set 8 | inongo
# Processing Record 17 of Set 8 | ponnani
# Processing Record 18 of Set 8 | aykhal
# Processing Record 19 of Set 8 | balakhta
# Processing Record 20 of Set 8 | prijepolje
# Processing Record 21 of Set 8 | kibala
# Processing Record 22 of Set 8 | mecca
# Processing Record 23 of Set 8 | zhigansk
# Processing Record 24 of Set 8 | sapao
# City not found. Skipping...
# Processing Record 25 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 26 of Set 8 | vestmannaeyjar
# Processing Record 27 of Set 8 | cangzhou
# Processing Record 28 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 8 | kohlu
# Processing Record 30 of Set 8 | khandyga
# Processing Record 31 of Set 8 | olafsvik
# Processing Record 32 of Set 8 | abong mbang
# Processing Record 33 of Set 8 | nome
# Processing Record 34 of Set 8 | nemuro
# Processing Record 35 of Set 8 | kuala terengganu
# Processing Record 36 of Set 8 | toyooka
# Processing Record 37 of Set 8 | isangel
# Processing Record 38 of Set 8 | nacunday
# City not found. Skipping...
# Processing Record 39 of Set 8 | ulaangom
# Processing Record 40 of Set 8 | tsienyane
# City not found. Skipping...
# Processing Record 41 of Set 8 | leningradskiy
# Processing Record 42 of Set 8 | satana
# Processing Record 43 of Set 8 | san jose
# Processing Record 44 of Set 8 | katete
# Processing Record 45 of Set 8 | steubenville
# Processing Record 46 of Set 8 | hoi an
# Processing Record 47 of Set 8 | kiruna
# Processing Record 48 of Set 8 | mount gambier
# Processing Record 49 of Set 8 | west odessa
# Processing Record 50 of Set 8 | balakhninskiy
# Processing Record 1 of Set 9 | channel-port aux basques
# Processing Record 2 of Set 9 | bo
# City not found. Skipping...
# Processing Record 3 of Set 9 | pisco
# Processing Record 4 of Set 9 | joshimath
# Processing Record 5 of Set 9 | hokitika
# Processing Record 6 of Set 9 | fremont
# Processing Record 7 of Set 9 | papa
# Processing Record 8 of Set 9 | grindavik
# Processing Record 9 of Set 9 | upernavik
# Processing Record 10 of Set 9 | nuuk
# Processing Record 11 of Set 9 | ruthin
# Processing Record 12 of Set 9 | yanam
# Processing Record 13 of Set 9 | bud
# Processing Record 14 of Set 9 | galich
# Processing Record 15 of Set 9 | shaunavon
# Processing Record 16 of Set 9 | sfantu gheorghe
# Processing Record 17 of Set 9 | duldurga
# Processing Record 18 of Set 9 | swift current
# Processing Record 19 of Set 9 | taicheng
# Processing Record 20 of Set 9 | san patricio
# Processing Record 21 of Set 9 | uhersky brod
# Processing Record 22 of Set 9 | izhma
# Processing Record 23 of Set 9 | gulshat
# City not found. Skipping...
# Processing Record 24 of Set 9 | tomatlan
# Processing Record 25 of Set 9 | ixtapa
# Processing Record 26 of Set 9 | las vegas
# Processing Record 27 of Set 9 | santander
# Processing Record 28 of Set 9 | alta floresta
# Processing Record 29 of Set 9 | pacifica
# Processing Record 30 of Set 9 | nevers
# Processing Record 31 of Set 9 | gobabis
# Processing Record 32 of Set 9 | tshikapa
# Processing Record 33 of Set 9 | namatanai
# Processing Record 34 of Set 9 | dargaville
# Processing Record 35 of Set 9 | atikokan
# Processing Record 36 of Set 9 | karachi
# Processing Record 37 of Set 9 | teahupoo
# Processing Record 38 of Set 9 | mont-dore
# Processing Record 39 of Set 9 | kinablangan
# Processing Record 40 of Set 9 | kiunga
# Processing Record 41 of Set 9 | zapolyarnyy
# Processing Record 42 of Set 9 | escanaba
# Processing Record 43 of Set 9 | laguna
# Processing Record 44 of Set 9 | saint-michel-des-saints
# Processing Record 45 of Set 9 | gladenbach
# Processing Record 46 of Set 9 | kankan
# Processing Record 47 of Set 9 | pemangkat
# Processing Record 48 of Set 9 | peleduy
# Processing Record 49 of Set 9 | dikson
# Processing Record 50 of Set 9 | linhares
# Processing Record 1 of Set 10 | ankpa
# Processing Record 2 of Set 10 | bengkulu
# Processing Record 3 of Set 10 | ormara
# Processing Record 4 of Set 10 | goma
# Processing Record 5 of Set 10 | dolores
# Processing Record 6 of Set 10 | aklavik
# Processing Record 7 of Set 10 | atar
# Processing Record 8 of Set 10 | teguise
# Processing Record 9 of Set 10 | yurginskoye
# Processing Record 10 of Set 10 | pizhanka
# Processing Record 11 of Set 10 | najran
# Processing Record 12 of Set 10 | bababe
# City not found. Skipping...
# Processing Record 13 of Set 10 | bogorodskoye
# Processing Record 14 of Set 10 | solvychegodsk
# Processing Record 15 of Set 10 | hay river
# Processing Record 16 of Set 10 | campbell river
# Processing Record 17 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 18 of Set 10 | farafangana
# Processing Record 19 of Set 10 | lasa
# Processing Record 20 of Set 10 | ostersund
# Processing Record 21 of Set 10 | rincon
# Processing Record 22 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 23 of Set 10 | petropavl
# Processing Record 24 of Set 10 | chumikan
# Processing Record 25 of Set 10 | ust-nera
# Processing Record 26 of Set 10 | cockburn town
# Processing Record 27 of Set 10 | eirunepe
# Processing Record 28 of Set 10 | fort-shevchenko
# Processing Record 29 of Set 10 | pangnirtung
# Processing Record 30 of Set 10 | goure
# Processing Record 31 of Set 10 | marsa matruh
# Processing Record 32 of Set 10 | lodja
# Processing Record 33 of Set 10 | walvis bay
# Processing Record 34 of Set 10 | dubovskoye
# Processing Record 35 of Set 10 | fianarantsoa
# Processing Record 36 of Set 10 | husavik
# Processing Record 37 of Set 10 | balabac
# Processing Record 38 of Set 10 | laiwu
# Processing Record 39 of Set 10 | concepcion de buenos aires
# Processing Record 40 of Set 10 | dromolaxia
# Processing Record 41 of Set 10 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 42 of Set 10 | umm lajj
# Processing Record 43 of Set 10 | preobrazheniye
# Processing Record 44 of Set 10 | key west
# Processing Record 45 of Set 10 | utrera
# Processing Record 46 of Set 10 | cravo norte
# Processing Record 47 of Set 10 | banjar
# Processing Record 48 of Set 10 | hofgeismar
# Processing Record 49 of Set 10 | la sarre
# Processing Record 50 of Set 10 | kathu
# Processing Record 1 of Set 11 | yining
# Processing Record 2 of Set 11 | karamay
# City not found. Skipping...
# Processing Record 3 of Set 11 | novikovo
# Processing Record 4 of Set 11 | pasni
# Processing Record 5 of Set 11 | alice springs
# Processing Record 6 of Set 11 | san cristobal
# Processing Record 7 of Set 11 | bonavista
# Processing Record 8 of Set 11 | champerico
# Processing Record 9 of Set 11 | zverinogolovskoye
# Processing Record 10 of Set 11 | raga
# Processing Record 11 of Set 11 | mayskiy
# Processing Record 12 of Set 11 | padang
# Processing Record 13 of Set 11 | naze
# Processing Record 14 of Set 11 | maine-soroa
# Processing Record 15 of Set 11 | dunedin
# Processing Record 16 of Set 11 | izumo
# Processing Record 17 of Set 11 | bagdarin
# Processing Record 18 of Set 11 | grand gaube
# Processing Record 19 of Set 11 | northam
# Processing Record 20 of Set 11 | port-gentil
# Processing Record 21 of Set 11 | kardla
# Processing Record 22 of Set 11 | pietersburg
# Processing Record 23 of Set 11 | zella-mehlis
# Processing Record 24 of Set 11 | laramie
# Processing Record 25 of Set 11 | isparta
# Processing Record 26 of Set 11 | vanimo
# Processing Record 27 of Set 11 | mayumba
# Processing Record 28 of Set 11 | kruisfontein
# Processing Record 29 of Set 11 | tasbuget
# City not found. Skipping...
# Processing Record 30 of Set 11 | biak
# Processing Record 31 of Set 11 | peace river
# Processing Record 32 of Set 11 | todos santos
# Processing Record 33 of Set 11 | swan hill
# Processing Record 34 of Set 11 | kahului
# Processing Record 35 of Set 11 | katobu
# Processing Record 36 of Set 11 | parit raja
# Processing Record 37 of Set 11 | sao felix do xingu
# Processing Record 38 of Set 11 | biltine
# Processing Record 39 of Set 11 | camopi
# Processing Record 40 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 41 of Set 11 | yumen
# Processing Record 42 of Set 11 | ye
# City not found. Skipping...
# Processing Record 43 of Set 11 | maniitsoq
# Processing Record 44 of Set 11 | anadyr
# Processing Record 45 of Set 11 | sao sebastiao
# Processing Record 46 of Set 11 | waipawa
# Processing Record 47 of Set 11 | kushima
# Processing Record 48 of Set 11 | salvacion
# Processing Record 49 of Set 11 | farah
# Processing Record 50 of Set 11 | jedburgh
# Processing Record 1 of Set 12 | agadir
# Processing Record 2 of Set 12 | medianeira
# Processing Record 3 of Set 12 | kiama
# Processing Record 4 of Set 12 | hirekerur
# Processing Record 5 of Set 12 | thayetmyo
# Processing Record 6 of Set 12 | ginda
# Processing Record 7 of Set 12 | hovd
# Processing Record 8 of Set 12 | suileng
# Processing Record 9 of Set 12 | bonfim
# Processing Record 10 of Set 12 | jiangyou
# Processing Record 11 of Set 12 | vsevolodo-vilva
# City not found. Skipping...
# Processing Record 12 of Set 12 | kabinda
# Processing Record 13 of Set 12 | pirgos
# Processing Record 14 of Set 12 | sainte-julienne
# Processing Record 15 of Set 12 | shawnee
# Processing Record 16 of Set 12 | vaxjo
# Processing Record 17 of Set 12 | el faiyum
# City not found. Skipping...
# Processing Record 18 of Set 12 | ewa beach
# Processing Record 19 of Set 12 | bay roberts
# Processing Record 20 of Set 12 | azimur
# City not found. Skipping...
# Processing Record 21 of Set 12 | westport
# Processing Record 22 of Set 12 | ishigaki
# Processing Record 23 of Set 12 | soyo
# Processing Record 24 of Set 12 | rodrigues alves
# Processing Record 25 of Set 12 | dolbeau
# City not found. Skipping...
# Processing Record 26 of Set 12 | lufilufi
# Processing Record 27 of Set 12 | banyo
# Processing Record 28 of Set 12 | galveston
# Processing Record 29 of Set 12 | verkhnevilyuysk
# Processing Record 30 of Set 12 | yurimaguas
# Processing Record 31 of Set 12 | umtata
# Processing Record 32 of Set 12 | taraz
# Processing Record 33 of Set 12 | lyndon
# Processing Record 34 of Set 12 | benguela
# Processing Record 35 of Set 12 | medvedka
# Processing Record 36 of Set 12 | arlit
# Processing Record 37 of Set 12 | changli
# Processing Record 38 of Set 12 | kayerkan
# Processing Record 39 of Set 12 | beloha
# Processing Record 40 of Set 12 | sorland
# Processing Record 41 of Set 12 | shebalino
# Processing Record 42 of Set 12 | warwick
# Processing Record 43 of Set 12 | trelew
# Processing Record 44 of Set 12 | harda
# Processing Record 45 of Set 12 | garowe
# Processing Record 46 of Set 12 | oriximina
# Processing Record 47 of Set 12 | george town
# Processing Record 48 of Set 12 | ajdabiya
# Processing Record 49 of Set 12 | port macquarie
# Processing Record 50 of Set 12 | gualeguay
# Processing Record 1 of Set 13 | borgarnes
# Processing Record 2 of Set 13 | uvat
# Processing Record 3 of Set 13 | tessalit
# Processing Record 4 of Set 13 | pietarsaari
# Processing Record 5 of Set 13 | manavalakurichi
# Processing Record 6 of Set 13 | kralendijk
# Processing Record 7 of Set 13 | havre-saint-pierre
# Processing Record 8 of Set 13 | dunhua
# Processing Record 9 of Set 13 | upata
# Processing Record 10 of Set 13 | bolanos de calatrava
# Processing Record 11 of Set 13 | cozumel
# Processing Record 12 of Set 13 | nelson bay
# Processing Record 13 of Set 13 | dinsor
# City not found. Skipping...
# Processing Record 14 of Set 13 | kirakira
# Processing Record 15 of Set 13 | chekhov
# Processing Record 16 of Set 13 | yazman
# Processing Record 17 of Set 13 | lewiston
# Processing Record 18 of Set 13 | pangody
# Processing Record 19 of Set 13 | chicama
# Processing Record 20 of Set 13 | chapais
# Processing Record 21 of Set 13 | shenjiamen
# Processing Record 22 of Set 13 | hede
# Processing Record 23 of Set 13 | manoharpur
# Processing Record 24 of Set 13 | medea
# Processing Record 25 of Set 13 | orhangazi
# Processing Record 26 of Set 13 | warmbad
# Processing Record 27 of Set 13 | collie
# Processing Record 28 of Set 13 | sikonge
# Processing Record 29 of Set 13 | wanxian
# Processing Record 30 of Set 13 | luwuk
# Processing Record 31 of Set 13 | manzhouli
# Processing Record 32 of Set 13 | mitsamiouli
# Processing Record 33 of Set 13 | ketchenery
# City not found. Skipping...
# Processing Record 34 of Set 13 | muyezerskiy
# Processing Record 35 of Set 13 | salme
# Processing Record 36 of Set 13 | tammisaari
# Processing Record 37 of Set 13 | ferrol
# Processing Record 38 of Set 13 | sambava
# Processing Record 39 of Set 13 | tabora
# Processing Record 40 of Set 13 | umm bab
# Processing Record 41 of Set 13 | rajakhera
# Processing Record 42 of Set 13 | biscarrosse
# Processing Record 43 of Set 13 | kununurra
# Processing Record 44 of Set 13 | nyimba
# Processing Record 45 of Set 13 | mariel
# Processing Record 46 of Set 13 | buariki
# City not found. Skipping...
# Processing Record 47 of Set 13 | katherine
# Processing Record 48 of Set 13 | vilyuysk
# Processing Record 49 of Set 13 | paamiut
# Processing Record 50 of Set 13 | kampong chhnang
# Processing Record 1 of Set 14 | rocha
# Processing Record 2 of Set 14 | funtua
# Processing Record 3 of Set 14 | kayes
# Processing Record 4 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 5 of Set 14 | chamalieres
# Processing Record 6 of Set 14 | makushino
# Processing Record 7 of Set 14 | mixtepec
# City not found. Skipping...
# Processing Record 8 of Set 14 | plettenberg bay
# Processing Record 9 of Set 14 | bitung
# Processing Record 10 of Set 14 | la ronge
# Processing Record 11 of Set 14 | itoman
# Processing Record 12 of Set 14 | shubarshi
# Processing Record 13 of Set 14 | morros
# Processing Record 14 of Set 14 | el alto
# Processing Record 15 of Set 14 | praia da vitoria
# Processing Record 16 of Set 14 | jacareacanga
# Processing Record 17 of Set 14 | niagara falls
# Processing Record 18 of Set 14 | san luis
# Processing Record 19 of Set 14 | aksarka
# Processing Record 20 of Set 14 | peniche
# Processing Record 21 of Set 14 | sangmelima
# Processing Record 22 of Set 14 | puri
# Processing Record 23 of Set 14 | vanavara
# Processing Record 24 of Set 14 | kautokeino
# Processing Record 25 of Set 14 | montepuez
# Processing Record 26 of Set 14 | lovrenc na pohorju
# Processing Record 27 of Set 14 | saurimo
# Processing Record 28 of Set 14 | pimenta bueno
# Processing Record 29 of Set 14 | posse
# Processing Record 30 of Set 14 | adwa
# Processing Record 31 of Set 14 | olga
# Processing Record 32 of Set 14 | mentougou
# Processing Record 33 of Set 14 | terney
# Processing Record 34 of Set 14 | plouzane
# Processing Record 35 of Set 14 | yatou
# Processing Record 36 of Set 14 | portobelo
# Processing Record 37 of Set 14 | zhireken
# Processing Record 38 of Set 14 | nieuw amsterdam
# Processing Record 39 of Set 14 | lokachi
# Processing Record 40 of Set 14 | gorontalo
# Processing Record 41 of Set 14 | bodden town
# Processing Record 42 of Set 14 | port hedland
# Processing Record 43 of Set 14 | yar-sale
# Processing Record 44 of Set 14 | scottsburgh
# City not found. Skipping...
# Processing Record 45 of Set 14 | gillette
# Processing Record 46 of Set 14 | quatre cocos
# Processing Record 47 of Set 14 | ucluelet
# Processing Record 48 of Set 14 | ayan
# Processing Record 49 of Set 14 | nyrob
# Processing Record 50 of Set 14 | evensk
# Processing Record 1 of Set 15 | tawang
# Processing Record 2 of Set 15 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 3 of Set 15 | roma
# Processing Record 4 of Set 15 | mayo
# Processing Record 5 of Set 15 | kant
# Processing Record 6 of Set 15 | presidencia roque saenz pena
# Processing Record 7 of Set 15 | tosya
# Processing Record 8 of Set 15 | dryden
# Processing Record 9 of Set 15 | marzuq
# Processing Record 10 of Set 15 | kasongo
# Processing Record 11 of Set 15 | hami
# Processing Record 12 of Set 15 | fort nelson
# Processing Record 13 of Set 15 | itaituba
# Processing Record 14 of Set 15 | stokmarknes
# Processing Record 15 of Set 15 | chizhou
# Processing Record 16 of Set 15 | crib point
# Processing Record 17 of Set 15 | iracoubo
# Processing Record 18 of Set 15 | mogadishu
# Processing Record 19 of Set 15 | tanout
# Processing Record 20 of Set 15 | kudahuvadhoo
# Processing Record 21 of Set 15 | terrak
# Processing Record 22 of Set 15 | bastia
# Processing Record 23 of Set 15 | berdigestyakh
# Processing Record 24 of Set 15 | hammerfest
# Processing Record 25 of Set 15 | calbuco
# Processing Record 26 of Set 15 | sorvag
# City not found. Skipping...
# Processing Record 27 of Set 15 | hobyo
# Processing Record 28 of Set 15 | kalur kot
# Processing Record 29 of Set 15 | hargeysa
# Processing Record 30 of Set 15 | pafos
# Processing Record 31 of Set 15 | temaraia
# City not found. Skipping...
# Processing Record 32 of Set 15 | port hawkesbury
# Processing Record 33 of Set 15 | shiraoi
# Processing Record 34 of Set 15 | arklow
# Processing Record 35 of Set 15 | roald
# Processing Record 36 of Set 15 | hays
# Processing Record 37 of Set 15 | cayenne
# Processing Record 38 of Set 15 | satitoa
# City not found. Skipping...
# Processing Record 39 of Set 15 | kilindoni
# Processing Record 40 of Set 15 | magadan
# Processing Record 41 of Set 15 | belaya gora
# Processing Record 42 of Set 15 | carmen
# Processing Record 43 of Set 15 | tura
# Processing Record 44 of Set 15 | katsuura
# Processing Record 45 of Set 15 | ileza
# Processing Record 46 of Set 15 | phatthalung
# Processing Record 47 of Set 15 | boguchany
# Processing Record 48 of Set 15 | tres lagoas
# Processing Record 49 of Set 15 | coahuayana
# Processing Record 50 of Set 15 | carupano
# Processing Record 1 of Set 16 | christchurch
# Processing Record 2 of Set 16 | tabiauea
# City not found. Skipping...
# Processing Record 3 of Set 16 | dire
# Processing Record 4 of Set 16 | mizan teferi
# Processing Record 5 of Set 16 | dudinka
# Processing Record 6 of Set 16 | saint-pierre
# Processing Record 7 of Set 16 | mahibadhoo
# Processing Record 8 of Set 16 | lakes entrance
# Processing Record 9 of Set 16 | aktash
# Processing Record 10 of Set 16 | telhara
# Processing Record 11 of Set 16 | saint-augustin
# Processing Record 12 of Set 16 | ha tinh
# Processing Record 13 of Set 16 | qasigiannguit
# Processing Record 14 of Set 16 | tahta
# Processing Record 15 of Set 16 | xichang
# Processing Record 16 of Set 16 | cedar city
# Processing Record 17 of Set 16 | auki
# Processing Record 18 of Set 16 | shimoda
# Processing Record 19 of Set 16 | arcata
# Processing Record 20 of Set 16 | suslovo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                   City Country    Lat     Lng  Maximum Hemperature  \
# 0    Euclides Da Cunha      BR -10.51  -39.02                61.84
# 1              Buarcos      PT  40.17   -8.88                62.01
# 2         Pueblo Nuevo      MX  23.38 -105.38                59.36
# 3               Hohhot      CN  40.81  111.65                82.40
# 4            Yebaishou      CN  41.40  119.64                93.65
# ..                 ...     ...    ...     ...                  ...
# 705         Cedar City      US  37.68 -113.06                75.20
# 706               Auki      SB  -8.77  160.70                84.58
# 707            Shimoda      JP  34.67  138.95                84.20
# 708             Arcata      US  40.87 -124.08                59.00
# 709            Suslovo      RU  56.22   88.12                75.97
#
#      Percent Humidity  Percent Cloudiness  Wind Speed Weather description
# 0                  99                  56        6.08          light rain
# 1                  93                 100        8.05     overcast clouds
# 2                  72                  92        6.17     overcast clouds
# 3                  42                  40        8.95    scattered clouds
# 4                  23                   0       16.42           clear sky
# ..                ...                 ...         ...                 ...
# 705                14                   1        8.05           clear sky
# 706                70                   7        1.70           clear sky
# 707                70                  20        6.93          few clouds
# 708                93                   1        2.71           clear sky
# 709                46                   0        7.27           clear sky
#
# [710 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
